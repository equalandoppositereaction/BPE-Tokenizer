# %%
# %run C:\Users\ADMIN\Desktop\BPE-Tokenizer\main.py
# Out:
# merge (101, 32) into 256
# merge (116, 104) into 257
# merge (100, 32) into 258
# merge (116, 32) into 259
# merge (115, 32) into 260
# merge (105, 110) into 261
# merge (101, 114) into 262
# merge (44, 32) into 263
# merge (97, 110) into 264
# merge (257, 256) into 265
# merge (46, 32) into 266
# merge (121, 32) into 267
# merge (101, 110) into 268
# merge (111, 117) into 269
# merge (111, 110) into 270
# merge (102, 32) into 271
# merge (111, 32) into 272
# merge (111, 114) into 273
# merge (101, 258) into 274
# merge (97, 114) into 275
# merge (261, 103) into 276
# merge (111, 271) into 277
# merge (115, 116) into 278
# merge (119, 97) into 279
# merge (104, 97) into 280
# merge (97, 108) into 281
# merge (114, 101) into 282
# merge (104, 105) into 283
# merge (276, 32) into 284
# merge (97, 32) into 285
# merge (116, 272) into 286
# merge (104, 256) into 287
# merge (264, 258) into 288
# merge (262, 32) into 289
# merge (279, 260) into 290
# merge (97, 259) into 291
# ...
