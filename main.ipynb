# %%
# %run C:\Users\ADMIN\Desktop\BPE-Tokenizer\main.py
# Out:
# merge (32, 116) into 256
# merge (104, 101) into 257
# merge (32, 97) into 258
# merge (105, 110) into 259
# merge (32, 119) into 260
# merge (256, 257) into 261
# merge (32, 111) into 262
# merge (32, 115) into 263
# merge (114, 101) into 264
# merge (104, 97) into 265
# merge (111, 117) into 266
# merge (32, 98) into 267
# merge (101, 114) into 268
# merge (101, 110) into 269
# merge (105, 116) into 270
# merge (101, 100) into 271
# merge (111, 110) into 272
# merge (32, 99) into 273
# merge (262, 102) into 274
# merge (259, 103) into 275
# merge (32, 102) into 276
# merge (97, 115) into 277
# merge (110, 100) into 278
# merge (105, 115) into 279
# merge (32, 109) into 280
# merge (32, 112) into 281
# merge (101, 115) into 282
# merge (111, 114) into 283
# merge (32, 100) into 284
# merge (97, 114) into 285
# merge (256, 111) into 286
# merge (32, 259) into 287
# merge (108, 108) into 288
# merge (32, 265) into 289
# merge (32, 110) into 290
# merge (32, 104) into 291
# ...
